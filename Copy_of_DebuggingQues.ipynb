# %% [markdown]
# <a href="https://colab.research.google.com/github/Remi97-hub/Datascience/blob/main/Copy_of_DebuggingQues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Experience': [1, 3, 5, 7, 10],
    'Projects': [2, 5, 8, 10, 12],
    'Performance': [3, 6, 7, 8, 9],
    'Department': ['HR', 'IT', 'Sales', 'IT', 'HR']
})

correlation_matrix = data[['Experience','Projects','Performance']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'Name': ['John', 'Emily', 'Michael', 'kishor', 'Sarah'],
    'Age': [25, 30, np.nan, 28, 22],
    'Salary': [50000, 60000, 55000, 58000, np.nan]
})

data['Age'].fillna(np.mean(data['Age']), inplace=True)
data['Salary'].fillna(np.mean(data['Salary']), inplace=True)
data
# Out:
# /tmp/ipython-input-3954265159.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(np.mean(data['Age']), inplace=True)
# /tmp/ipython-input-3954265159.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Salary'].fillna(np.mean(data['Salary']), inplace=True)
#       Name    Age   Salary
# 0     John  25.00  50000.0
# 1    Emily  30.00  60000.0
# 2  Michael  26.25  55000.0
# 3   kishor  28.00  58000.0
# 4    Sarah  22.00  55750.0

# %%
from scipy import stats

group1 = [120, 125, 130, 122, 128]
group2 = [110, 115, 108, 102, 107]

t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-Statistic: {t_stat}, P-Value: {p_value}")

if p_value <= 0.05:
    print("Reject the null hypothesis: Significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# T-Statistic: 5.921023912553299, P-Value: 0.0003532844625064416
# Reject the null hypothesis: Significant difference.

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({'Salary': [30000, 32000, 34000, 500000, 36000, 37000, 39000, 41000, 42000, 450000]})

#outlier_threshold = data['Salary'].mean() + 3 * data['Salary'].std()
q1,q3=np.percentile(data,[25,75])
iqr=q3-q1
lower_bound=q1-(1.5*iqr)
upper_bound=q3+(1.5*iqr)

outliers = data[(data['Salary']<lower_bound) |(data['Salary']>upper_bound)]

print("Outliers:", outliers)
# Out:
# Outliers:    Salary
# 3  500000
# 9  450000

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = np.random.normal(50, 10, 1000)

plt.hist(data,)
plt.title("PDF Plot")
plt.show()
